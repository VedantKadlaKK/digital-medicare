# %%
from tkinter import *
from tkinter import messagebox
import numpy as np
import pandas as pd
import tkinter as tk
from PIL import Image , ImageTk

l1=['itching','skin_rash','nodal_skin_eruptions','continuous_sneezing','shivering','chills','joint_pain',
    'stomach_pain','acidity','ulcers_on_tongue','muscle_wasting','vomiting','burning_micturition','spotting_ urination','fatigue',
    'weight_gain','anxiety','cold_hands_and_feets','mood_swings','weight_loss','restlessness','lethargy','patches_in_throat',
    'irregular_sugar_level','cough','high_fever','sunken_eyes','breathlessness','sweating','dehydration','indigestion',
    'headache','yellowish_skin','dark_urine','nausea','loss_of_appetite','pain_behind_the_eyes','back_pain','constipation',
    'abdominal_pain','diarrhoea','mild_fever','yellow_urine','yellowing_of_eyes','acute_liver_failure','fluid_overload',
    'swelling_of_stomach','swelled_lymph_nodes','malaise','blurred_and_distorted_vision','phlegm','throat_irritation',
    'redness_of_eyes','sinus_pressure','runny_nose','congestion','chest_pain','weakness_in_limbs','fast_heart_rate',
    'pain_during_bowel_movements','pain_in_anal_region','bloody_stool','irritation_in_anus','neck_pain','dizziness','cramps',
    'bruising','obesity','swollen_legs','swollen_blood_vessels','puffy_face_and_eyes','enlarged_thyroid','brittle_nails',
    'swollen_extremeties','excessive_hunger','extra_marital_contacts','drying_and_tingling_lips','slurred_speech','knee_pain','hip_joint_pain',
    'muscle_weakness','stiff_neck','swelling_joints','movement_stiffness','spinning_movements','loss_of_balance','unsteadiness','weakness_of_one_body_side',
    'loss_of_smell','bladder_discomfort','foul_smell_of urine','continuous_feel_of_urine','passage_of_gases','internal_itching','toxic_look_(typhos)',
    'depression','irritability','muscle_pain','altered_sensorium','red_spots_over_body','belly_pain','abnormal_menstruation','dischromic _patches',
    'watering_from_eyes','increased_appetite','polyuria','family_history','mucoid_sputum','rusty_sputum','lack_of_concentration','visual_disturbances',
    'receiving_blood_transfusion','receiving_unsterile_injections','coma','stomach_bleeding','distention_of_abdomen','history_of_alcohol_consumption',
    'fluid_overload','blood_in_sputum','prominent_veins_on_calf','palpitations','painful_walking','pus_filled_pimples','blackheads','scurring','skin_peeling',
    'silver_like_dusting','small_dents_in_nails','inflammatory_nails','blister','red_sore_around_nose','yellow_crust_ooze']

disease=['Fungal infection','Allergy','GERD','Chronic cholestasis','Drug Reaction',
        'Peptic ulcer diseae','AIDS','Diabetes','Gastroenteritis','Bronchial Asthma','Hypertension',
        ' Migraine','Cervical spondylosis',
        'Paralysis (brain hemorrhage)','Jaundice','Malaria','Chicken pox','Dengue','Typhoid','hepatitis A',
'Hepatitis B','Hepatitis C','Hepatitis D','Hepatitis E','Alcoholic hepatitis','Tuberculosis',
'Common Cold','Pneumonia','Dimorphic hemmorhoids(piles)',
'Heartattack','Varicoseveins','Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis',
'Arthritis','(vertigo) Paroymsal  Positional Vertigo','Acne','Urinary tract infection','Psoriasis',
'Impetigo']

g1=['Fungal_infection','Allergy','GERD','Chronic_cholestasis','Drug_Reaction','Peptic_ulcer_diseae','AIDS','Diabetes',
'Gastroenteritis','Bronchial_Asthma','Hypertension','Migraine','Cervical_spondylosis','brain_hemorrhage','Jaundice',
'Malaria','Chicken_pox','Dengue','Typhoid','hepatitis_A','Hepatitis_B','Hepatitis_C','Hepatitis_D','Hepatitis_E',
'Alcoholic_hepatitis','Tuberculosis','Common_Cold','Pneumonia','Dimorphic_hemmorhoidspiles','Heartattack','Varicoseveins',
'Hypothyroidism','Hyperthyroidism','Hypoglycemia','Osteoarthristis','Arthritis','vertigo_Paroymsal_Positional_Vertigo',
'Acne','Urinary_tract_infection','Psoriasis','Impetigo']

medic=['fluconazole','loratadine (Claritin)','omeprazole (Prilosec)','ursodeoxycholic acid (UDCA)','cetirizine',
'cimetidine','zidovudine','Metformin 500','promethazine','Theophylline','furosemide','topiramate',
'ibuprofen','warfarin','ursodeoxycholic acid tablets','proguanil','acyclovir','Acetaminophen','Ceftriaxone',
'Intravenous (IV) fluids','entecavir','ledipasvir','peginterferon','No Medication','Pentoxifylline',
'Isoniazid (INH) 300mg','Benadryl','azithromycin','hydrocortisone','Nitroglycerin','Sclerotherapy',
'levothyroxine','propylthiouracil','glucagon','naproxen','sulfasalazine','Epley maneuver','Benzoyl peroxide',
'Nitrofurantoin','cyclosporine','erythromycin 250mg']

l2=[]
for x in range(0,len(l1)):
    l2.append(0)
    
g2=[]
for x in range(0,len(g1)):
    g2.append(0)

# TESTING DATA
tr=pd.read_csv("Testing.csv")
tr.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)

O_test= tr[l1]
U_test = tr[["prognosis"]]
np.ravel(U_test)

kr=pd.read_csv("medit.csv")
kr.replace({'proginosis':{'fluconazole':0,'loratadine (Claritin)':1,'omeprazole (Prilosec)':2,'ursodeoxycholic acid (UDCA)':3,'cetirizine':4,
'cimetidine':5,'zidovudine':6,'Metformin 500':7,'promethazine':8,'Theophylline':9,'furosemide':10,'topiramate':11,
'ibuprofen':12,'warfarin':13,'ursodeoxycholic acid tablets':14,'proguanil':15,'acyclovir':16,'Acetaminophen':17,'Ceftriaxone':18,
'Intravenous (IV) fluids':19,'entecavir':20,'ledipasvir':21,'peginterferon':22,'No Medication':23,'Pentoxifylline':24,
'Isoniazid (INH) 300mg':25,'Benadryl':26,'azithromycin':27,'hydrocortisone':28,'Nitroglycerin':29,'Sclerotherapy':30,
'levothyroxine':31,'propylthiouracil':32,'glucagon':33,'naproxen':34,'sulfasalazine':35,'Epley maneuver':36,'Benzoyl peroxide':37,
'Nitrofurantoin':38,'cyclosporine':39,'erythromycin 250mg':40}},inplace=True)

X_test= kr[g1]
y_test = kr[["proginosis"]]
np.ravel(y_test)

# TRAINING DATA
df=pd.read_csv("Training.csv")

df.replace({'prognosis':{'Fungal infection':0,'Allergy':1,'GERD':2,'Chronic cholestasis':3,'Drug Reaction':4,
'Peptic ulcer diseae':5,'AIDS':6,'Diabetes ':7,'Gastroenteritis':8,'Bronchial Asthma':9,'Hypertension ':10,
'Migraine':11,'Cervical spondylosis':12,
'Paralysis (brain hemorrhage)':13,'Jaundice':14,'Malaria':15,'Chicken pox':16,'Dengue':17,'Typhoid':18,'hepatitis A':19,
'Hepatitis B':20,'Hepatitis C':21,'Hepatitis D':22,'Hepatitis E':23,'Alcoholic hepatitis':24,'Tuberculosis':25,
'Common Cold':26,'Pneumonia':27,'Dimorphic hemmorhoids(piles)':28,'Heart attack':29,'Varicose veins':30,'Hypothyroidism':31,
'Hyperthyroidism':32,'Hypoglycemia':33,'Osteoarthristis':34,'Arthritis':35,
'(vertigo) Paroymsal  Positional Vertigo':36,'Acne':37,'Urinary tract infection':38,'Psoriasis':39,
'Impetigo':40}},inplace=True)

O= df[l1]

U = df[["prognosis"]]
np.ravel(U)

gf=pd.read_csv("trainmedit.csv")

gf.replace({'proginosis':{'fluconazole':0,'loratadine (Claritin)':1,'omeprazole (Prilosec)':2,'ursodeoxycholic acid (UDCA)':3,'cetirizine':4,
'cimetidine':5,'zidovudine':6,'Metformin 500':7,'promethazine':8,'Theophylline':9,'furosemide':10,'topiramate':11,
'ibuprofen':12,'warfarin':13,'ursodeoxycholic acid tablets':14,'proguanil':15,'acyclovir':16,'Acetaminophen':17,'Ceftriaxone':18,
'Intravenous (IV) fluids':19,'entecavir':20,'ledipasvir':21,'peginterferon':22,'No Medication':23,'Pentoxifylline':24,
'Isoniazid (INH) 300mg':25,'Benadryl':26,'azithromycin':27,'hydrocortisone':28,'Nitroglycerin':29,'Sclerotherapy':30,
'levothyroxine':31,'propylthiouracil':32,'glucagon':33,'naproxen':34,'sulfasalazine':35,'Epley maneuver':36,'Benzoyl peroxide':37,
'Nitrofurantoin':38,'cyclosporine':39,'erythromycin 250mg':40}},inplace=True)

X= gf[g1]

y = gf[["proginosis"]]
np.ravel(y)


def order1():
    if entryC.get()=='':
        messagebox.showwarning("Warning", "Please\nAdd Details")
    if entryA.get()=='':
        messagebox.showwarning("Warning", "Please\nAdd Details")
    else:
        frame1.pack()
        frame2.pack_forget()
        frame1a.pack_forget()
        frame1b.pack_forget()
        frame3.pack_forget()
        
def goback2():
    mainwindow.configure(bg='#87CEEB')
    frame1b.pack_forget()
    frame1a.pack_forget()
    frame1.pack()
    frame2.pack_forget()
    frame3.pack_forget()
    
        
def proc():
    frame1b.pack()
    frame1a.pack_forget()
    frame1.pack_forget()
    frame2.pack_forget()
    frame3.pack_forget()

def symp():
    mainwindow.configure(bg = '#2a9df4')
    frame1.pack_forget()
    frame2.pack()
    
def med():
    mainwindow.configure(bg = '#2a9df4')
    frame1.pack_forget()
    frame2.pack_forget()
    frame3.pack()
    
def adddate2():
    date_2 = entryC.get()
    if entryC.get()=='':
        messagebox.showwarning("Warning", "Date Not Added\nPlease Add Date")
    else:
        datafile = open('patient.txt', 'a')
        datafile.write('\n' + 'Patient Details' + '\n '+'Date     :   ' + date_2 + '\n')
        datafile.close()
        label2a_121.configure(text = 'Date : ' + date_2)

def addata():
    data_2 = t3.get("1.0", "end-1c")
    print(data_2)
    if data_2=='':
        messagebox.showwarning("Warning", "Data Not Added\nPlease Add Data")
    else:
        datafile = open('patient.txt', 'a')
        datafile.write('\n' + 'Patient Details' + '\n '+'Disease     :   ' + data_2 + '\n')
        datafile.close()
        
def addata2():
    data_3 = d3.get("1.0", "end-1c")
    print(data_3)
    if data_3=='':
        messagebox.showwarning("Warning", "Data Not Added\nPlease Add Data")
    else:
        datafile = open('patient.txt', 'a')
        datafile.write('\n' + '\n '+'medicine     :   ' + data_3 + '\n')
        datafile.close()
        
        
def resetdate():
    label2a_121.configure(text = ' ENTER DATE ')
    entryC.delete(0, END)
    
def adddetail():
    det_1 = entryA.get()
    if entryA.get()=='':
        messagebox.showwarning("Warning", "details not Added\nPlease Add ") 
    else:
        datafile = open('patient.txt', 'a')
        datafile.write('patient     :   ' + det_1 + '\n')
        datafile.close()
        label5.configure(text = '\nHello ' + det_1 + '\n...' )
    
def message():
    if (Symptom1.get() == "None" and  Symptom2.get() == "None" and Symptom3.get() == "None" and Symptom4.get() == "None" and Symptom5.get() == "None"):
        messagebox.showinfo("OPPS!!", "ENTER  SYMPTOMS PLEASE")
    else :
        NaiveBayes()

def NaiveBayes():
    from sklearn.naive_bayes import MultinomialNB
    gnb = MultinomialNB()
    gnb=gnb.fit(O,np.ravel(U))
    from sklearn.metrics import accuracy_score
    U_pred = gnb.predict(O_test)
    print(accuracy_score(U_test, U_pred))
    print(accuracy_score(U_test, U_pred, normalize=False))

    psymptoms = [Symptom1.get(),Symptom2.get(),Symptom3.get(),Symptom4.get(),Symptom5.get()]

    for k in range(0,len(l1)):
        for z in psymptoms:
            if(z==l1[k]):
                l2[k]=1

    inputtest = [l2]
    predict = gnb.predict(inputtest)
    predicted=predict[0]

    h='no'
    for a in range(0,len(disease)):
        if(disease[predicted] == disease[a]):
            h='yes'
            break

    if (h=='yes'):
        t3.delete("1.0", END)
        t3.insert(END, disease[a])
    else:
        t3.delete("1.0", END)
        t3.insert(END, "No Disease")
        
        

    
def goback1():
    frame1a.pack()
    frame1.pack_forget()
    frame1b.pack_forget()
    frame2.pack_forget()
    frame3.pack_forget()
    
def message1():
    if (Disea1.get() == "None"):
        messagebox.showinfo("OPPS!!", "ENTER  DISEASE PLEASE")
    else :
        NaiveBayes1()

def NaiveBayes1():
    from sklearn.naive_bayes import MultinomialNB
    gnb = MultinomialNB()
    gnb=gnb.fit(X,np.ravel(y))
    from sklearn.metrics import accuracy_score
    y_pred = gnb.predict(X_test)
    print(accuracy_score(y_test, y_pred))
    print(accuracy_score(y_test, y_pred, normalize=False))

    pdisease = [Disea1.get()]

    for k in range(0,len(g1)):
        for z in pdisease:
            if(z==g1[k]):
                g2[k]=1

    inputtest = [g2]
    predict = gnb.predict(inputtest)
    predicted=predict[0]

    h='no'
    for a in range(0,len(medic)):
        if(medic[predicted] == medic[a]):
            h='yes'
            break

    if (h=='yes'):
        d3.delete("1.0", END)
        d3.insert(END, medic[a])
    else:
        d3.delete("1.0", END)
        d3.insert(END, "No Disease")
        
mainwindow=tk.Tk()
mainwindow.title('Digital Medicare')
mainwindow.geometry('1442x2140')
mainwindow.configure(bg = '#87CEEB')


#frame1a________________________________________

frame1a=tk.Frame(mainwindow,bg = '#87CEEB')
tk.Label1a=Label(frame1a,text='DIGITAL MEDICARE',font='times 40',bg='#87ceeb')
tk.Label1a.pack()

tk.Label1c=Label(frame1a,text='\n\n',font='times 40',bg='#87ceeb')
tk.Label1c.pack()

tk.Label1b=tk.Label(frame1a,text='Digital Medicare is a software\nthat provides you a accurate disease prediction according to your symptons \nand then recommend the medicine for that disease ',font='times 20', bg = '#87CEEB')
tk.Label1b.pack()

tk.Label1d=Label(frame1a,text='\n\n',font='times 40',bg='#87ceeb')
tk.Label1d.pack()

button1a=tk.Button(frame1a,text='PROCEED',command=proc,font='times 15' , bg='#90EE90')
button1a.pack()

#frame1b________________________________________

frame1b = tk.Frame(mainwindow , bg = '#87CEEB')

label2a = tk.Label(frame1b, text = '\nPatient Details \n...' , bg = '#87CEEB' , font = 'helvetica 20' )
label2a.pack()

label2a_121= tk.Label(frame1b, text = 'ENTER DATE' , bg = '#87CEEB' , font = 'helvetica 15' )
label2a_121.pack()

label2a44 = tk.Label(frame1b, text = '\n' , bg = '#87CEEB' , font = 'helvetica 15' )
label2a44.pack()

entryC = tk.Entry(frame1b, width = 10)
entryC.pack()

labelgap1 = tk.Label(frame1b , text = '\n'  , bg = '#87CEEB' )
labelgap1.pack()


framebuttx= tk.Frame(frame1b , bg = '#87ceeb')

button4_111 = tk.Button(framebuttx, text = 'ADD DATE' , command = adddate2 , bg = '#90EE90' , font = 'helvetica 15')

label6_111 = tk.Label(framebuttx , text = '                                       '  , bg = '#87CEEB' )

button4_112 = tk.Button(framebuttx, text = 'RESET DATE' , command = resetdate , bg = '#90EE90' , font = 'helvetica 15')

button4_111.grid(row=0, column = 1)
label6_111.grid(row =1 , column = 1)
button4_112.grid(row=2, column = 1)

framebuttx.pack()

label5 = tk.Label(frame1b, text = '\nENTER PATIENT NAME \nAND PHONE NO. \n...' , bg = '#87CEEB' , font = 'helvetica 20' )
label5.pack()

entryA = tk.Entry(frame1b, width = 20)
entryA.pack()

label5_1 = tk.Label(frame1b, text = '\n', bg = '#87CEEB' )
label5_1.pack()

button3 = tk.Button(frame1b, text = 'ADD \n DETAILS' , command = adddetail , bg = '#90EE90' , font = 'helvetica 15')
button3.pack()

label6 = tk.Label(frame1b, text = '\nIF COMPLETED \n...\n' , bg = '#87CEEB' , font = 'helvetica 15' )
label6.pack()

framebutton2 = tk.Frame(frame1b, bg = '#87CEEB' )

button4 = tk.Button(framebutton2, text = 'PROCEED\n', command = order1 , bg = '#90EE90' , font = 'helvetica 15')

label6_1 =tk.Label(framebutton2 , text = '                                       '  , bg = '#87CEEB' )

button_return_1 =tk.Button(framebutton2, text = 'GO \n BACK' , command = goback1 , bg = '#90EE90' , font = 'helvetica 15')

button4.grid(row=0, column = 0)
label6_1.grid(row =0 , column = 1)
button_return_1.grid(row=0, column = 2)

framebutton2.pack()


#frame1_____________________________________________________________________________
frame1=tk.Frame(mainwindow, bg = '#87CEEB')
tk.Label1=tk.Label(frame1,text='Digital Medicare',font='times 40', bg = '#87CEEB')
tk.Label1.pack()

tk.Label2=tk.Label(frame1,text='\n Choose Type\n',font='times 20', bg = '#87CEEB')
tk.Label2.pack()

frbutton1=tk.Frame(frame1 , bg = '#87CEEB')
but1=tk.Button(frbutton1,text='Symptoms',command=symp,font='times 15',bg='#90EE90')

lab1=tk.Label(frbutton1,text='                                                                    ', bg = '#87CEEB')

but2=tk.Button(frbutton1,text='Medicine',command=med,font='times 15',bg='#90EE90')
lab1a=tk.Label(frbutton1,text='                                    \n\n\n\n\n\n\n\n\n                                  ', bg = '#87CEEB')

buttt1c=tk.Button(frbutton1, text="     Quit     ", command=mainwindow.destroy,font='times 15', bg ='#90EE90')

but1.grid(row=3,column=0)
lab1.grid(row=3,column=1)
but2.grid(row=3,column=2)
lab1a.grid(row=4,column=1)
buttt1c.grid(row=5,column=1)




frbutton1.pack()

#frame3________________________________________________________________________________________

frame3=tk.Frame(mainwindow , bg='#2a9df4')

Disea1 = StringVar()
Disea1.set(None)

d2 = tk.Label(frame3, justify=CENTER, text=" Medicine Prediction From Diseases ",bg='#2a9df4')
d2.config(font=("Helvetica", 30))
d2.grid(row=1, column=0, columnspan=2, padx=100)

NameLb11 =tk.Label(frame3, text="" ,bg='#2a9df4')
NameLb11.config(font=("Helvetica", 20))
NameLb11.grid(row=5, column=1, pady=10,  sticky=W)

d1Lb = tk.Label(frame3,  text="DISEASE",bg='#2a9df4')
d1Lb.config(font=("Helvetica", 30))
d1Lb.grid(row=7, column=0, pady=10 , sticky=W)

dr = Button(frame3, text="PREDICT",height=2, width=20, command=message1,bg='#90EE90')
dr.config(font=("Helvetica", 15))
dr.grid(row=19, column=0,pady=10)

#OPTIONS = sorted(symptoms)
OPTIONS = sorted(g1)

d1En = OptionMenu(frame3, Disea1,*OPTIONS)
d1En.grid(row=7, column=1)

NamedLb = tk.Label(frame3, text="",bg='#2a9df4')
NamedLb.config(font=("Helvetica", 20))
NamedLb.grid(row=13, column=1, pady=10,  sticky=W)

NamedLb = tk.Label(frame3, text="",bg='#2a9df4')
NamedLb.config(font=("Helvetica", 15))
NamedLb.grid(row=18, column=1, pady=10,  sticky=W)

d3 = tk.Text(frame3, height=2, width=20)
d3.config(font=("Helvetica", 20))
d3.grid(row=19, column=1 , padx=10)


NamedLb = tk.Label(frame3, text="",bg='#2a9df4')
NamedLb.config(font=("Helvetica", 20))
NamedLb.grid(row=20, column=1, pady=10,  sticky=W)

dr2 = Button(frame3, text="BACK",height=2, width=20, command=goback2,bg='#90EE90')
dr2.config(font=("Helvetica", 15))
dr2.grid(row=21, column=1,pady=10)

dpr2 = Button(frame3, text="ADD DATA",height=2, width=20, command=addata2,bg='#90EE90')
dpr2.config(font=("Helvetica", 15))
dpr2.grid(row=21, column=0,pady=10)


#frame2_________________________________________________________________________________________
frame2=tk.Frame(mainwindow , bg='#2a9df4')

Symptom1 = StringVar()
Symptom1.set(None)
Symptom2 = StringVar()
Symptom2.set(None)
Symptom3 = StringVar()
Symptom3.set(None)
Symptom4 = StringVar()
Symptom4.set(None)
Symptom5 = StringVar()
Symptom5.set(None)
location = StringVar()
location.set(None)

w2 = tk.Label(frame2, justify=CENTER, text=" Disease Prediction From Symptoms ",bg='#2a9df4')
w2.config(font=("Helvetica", 30))
w2.grid(row=1, column=0, columnspan=2, padx=100)

NameLb1 =tk.Label(frame2, text="" ,bg='#2a9df4')
NameLb1.config(font=("Helvetica", 20))
NameLb1.grid(row=5, column=1, pady=10,  sticky=W)

S1Lb = tk.Label(frame2,  text="Symptom 1",bg='#2a9df4')

S1Lb.config(font=("Helvetica", 15))
S1Lb.grid(row=7, column=0, pady=10 , sticky=W)

S2Lb = tk.Label(frame2,  text="Symptom 2",bg='#2a9df4')
S2Lb.config(font=("Helvetica", 15))
S2Lb.grid(row=8, column=0, pady=10, sticky=W)

S3Lb = tk.Label(frame2,  text="Symptom 3",bg='#2a9df4')
S3Lb.config(font=("Helvetica", 15))
S3Lb.grid(row=9, column=0, pady=10, sticky=W)

S4Lb = tk.Label(frame2,  text="Symptom 4",bg='#2a9df4')
S4Lb.config(font=("Helvetica", 15))
S4Lb.grid(row=10, column=0, pady=10, sticky=W)

S5Lb = tk.Label(frame2,  text="Symptom 5",bg='#2a9df4')
S5Lb.config(font=("Helvetica", 15))
S5Lb.grid(row=11, column=0, pady=10, sticky=W)


lr = Button(frame2, text="PREDICT",height=2, width=20, command=message,bg='#90EE90')
lr.config(font=("Helvetica", 15))
lr.grid(row=15, column=0)

#OPTIONS = sorted(symptoms)
OPTIONS = sorted(l1)

S1En = OptionMenu(frame2, Symptom1,*OPTIONS)
S1En.grid(row=7, column=1)

S2En = OptionMenu(frame2, Symptom2,*OPTIONS)
S2En.grid(row=8, column=1)

S3En = OptionMenu(frame2, Symptom3,*OPTIONS)
S3En.grid(row=9, column=1)

S4En = OptionMenu(frame2, Symptom4,*OPTIONS)
S4En.grid(row=10, column=1)

S5En = OptionMenu(frame2, Symptom5,*OPTIONS)
S5En.grid(row=11, column=1)

NameLb = tk.Label(frame2, text="",bg='#2a9df4')
NameLb.config(font=("Helvetica", 20))
NameLb.grid(row=13, column=1, pady=10,  sticky=W)

NameLb = tk.Label(frame2, text="",bg='#2a9df4')
NameLb.config(font=("Helvetica", 15))
NameLb.grid(row=18, column=1, pady=10,  sticky=W)


t3 = tk.Text(frame2, height=2, width=20)
t3.config(font=("Helvetica", 20))
t3.grid(row=15, column=1 , padx=40)

NameLb = tk.Label(frame2, text="",bg='#2a9df4')
NameLb.config(font=("Helvetica", 20))
NameLb.grid(row=20, column=1, pady=10,  sticky=W)

lr2 = Button(frame2, text="BACK",height=2, width=20, command=goback2,bg='#90EE90')
lr2.config(font=("Helvetica", 15))
lr2.grid(row=20, column=1,pady=10)

l2r2 = Button(frame2, text="ADD DATA",height=2, width=20,command=addata,bg='#90EE90')
l2r2.config(font=("Helvetica", 15))
l2r2.grid(row=20, column=0,pady=10)

goback1()


mainwindow.mainloop()
# Out:
# 1.0
# 41
# C:\Users\Vedant\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# Fungal infection
# 1.0
# 41
# C:\Users\Vedant\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# hydrocortisone
